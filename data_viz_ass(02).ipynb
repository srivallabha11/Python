# %%
import numpy as ny

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as snr

# %% [markdown]
# >use the fitbit dataset shared for data visualization

# %%
Fb=pd.read_csv('/content/FitBit data.csv')

# %%
Fb.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    3/25/2016       11004           7.11             7.11
# 1  1503960366    3/26/2016       17609          11.55            11.55
# 2  1503960366    3/27/2016       12736           8.53             8.53
# 3  1503960366    3/28/2016       13231           8.93             8.93
# 4  1503960366    3/29/2016       12041           7.85             7.85
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
# 3                       0.0                3.19                      0.79
# 4                       0.0                2.16                      1.09
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# ...

# %%
Fb.tail()
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 452  8877689391     4/8/2016       23014      20.389999        20.389999
# 453  8877689391     4/9/2016       16470       8.070000         8.070000
# 454  8877689391    4/10/2016       28497      27.530001        27.530001
# 455  8877689391    4/11/2016       10622       8.060000         8.060000
# 456  8877689391    4/12/2016        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 452                       0.0               11.10                      0.63
# 453                       0.0                0.00                      0.02
# 454                       0.0               21.92                      1.12
# 455                       0.0                1.47                      0.15
# 456                       0.0                0.00                      0.00
#
# ...

# %%
#bar graph
Fb.plot(kind='bar')

# %% [markdown]
# since we have large number of data,we can see the overlapping one another

# %%
Fb.plot(kind='barh')

# %%
#histogram
Fb.plot(kind='hist')

# %%
Fb.plot(kind='hist',bins=20)

# %%
Fb['TotalSteps'].diff().plot(kind='hist',bins=20)

# %% [markdown]
# the above graph shows a bell curve showing the steps covered

# %%
Fb['VeryActiveDistance'].diff().plot(kind='hist',bins=20)

# %% [markdown]
# >on an average the max distance covered is around 310-320 in a regular interval of time

# %%
Fb['Calories'].diff().plot(kind='hist',bins=50)

# %% [markdown]
# >the graph shows the max calories burned w.r.to max.distance covered,the resultant curve is similar to bell shaved or gaussian curve

# %%
Fb['ModeratelyActiveDistance'].diff().plot(kind='hist',bins=100)

# %%
its similar to the curve we got in above case considering the distance frequency

# %%
Fb['TotalDistance'].diff().plot(kind='hist',bins=200)

# %%
#scatter plot
Fb.plot.scatter(x='TotalSteps',y='TotalDistance')

# %%
Fb.plot.scatter(x='TotalSteps',y='TrackerDistance',color='y')

# %%
Fb.plot.scatter(x='FairlyActiveMinutes',y='VeryActiveMinutes',color='g')

# %%
Fb.plot.scatter(x='FairlyActiveMinutes',y='VeryActiveMinutes',c='LightlyActiveMinutes')

# %%
#catplot
snr.catplot(x='Calories',y='TotalDistance',data=Fb)

# %%
snr.catplot(x='TotalSteps',y='TotalDistance',data=Fb)

# %%
snr.catplot(x='VeryActiveMinutes',y='VeryActiveDistance',data=Fb)

# %%
#box plot
snr.catplot(x='Calories',y='TotalDistance',kind='box',data=Fb,hue="LoggedActivitiesDistance")

# %%
snr.catplot(x='Calories',y='TotalDistance',kind='box',data=Fb)

# %%
#pairplot
snr.pairplot(Fb,x_vars=['Calories','VeryActiveMinutes','TotalDistance'],y_vars=['TotalSteps'],size=10)
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
